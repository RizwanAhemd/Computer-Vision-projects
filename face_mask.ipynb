# %% [markdown]
# <a href="https://colab.research.google.com/github/RizwanAhemd/Computer-Vision-projects/blob/main/face_mask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile

# %%
ds=zipfile.ZipFile("/content/mask.v1i.yolov11.zip")

# %%
ds.extractall()

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 30.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model=YOLO("yolo11n.pt")

# %%
model.train(data="/content/data.yaml",epochs=80)
# Out:
# Ultralytics 8.3.245 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
pred=model.predict("/content/mask.jpg")
# Out:
# image 1/1 /content/mask.jpg: 384x640 5 faces, 1 face_mask, 1 mask, 46.9ms
# Speed: 5.8ms preprocess, 46.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)

# %%
pred[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>

# %%
pred[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>

# %%
pred1=model.predict("/content/face_mask2.jpg")
# Out:
# image 1/1 /content/face_mask2.jpg: 416x640 5 faces, 2 face_masks, 1 mask, 51.3ms
# Speed: 3.9ms preprocess, 51.3ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)

# %%
pred1[0].show()
# Out:
# <PIL.Image.Image image mode=RGB size=281x179>
