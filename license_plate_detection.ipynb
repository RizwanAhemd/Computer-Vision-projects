# %% [markdown]
# <a href="https://colab.research.google.com/github/RizwanAhemd/Computer-Vision-projects/blob/main/license_plate_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile

# %%
path = zipfile.ZipFile("/content/License Plate Recognition.v6i.yolov11.zip")

# %%
path.extractall()

# %%
# !pip install ultralytics
from ultralytics import YOLO
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 29.1 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolov8n.pt")

# %%
# pred=model.predict("/content/valid/images/021620_152b_jpeg_jpg.rf.f2037a2bab90c5b9159ee7ec0ec00732.jpg")

# %%
# pred[0].show()

# %%
model.train(data="/content/data.yaml",epochs=40)
# Out:
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
pred1=model.predict("/content/car_license_plates.jpg")
pred1[0].show()
# Out:
# image 1/1 /content/car_license_plates.jpg: 224x640 2 License-Plates, 7.1ms
# Speed: 2.1ms preprocess, 7.1ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 640)
# <PIL.Image.Image image mode=RGB size=389x130>

# %%
pred2=model.predict("/content/license_plate.jpg")
pred2[0].show()
# Out:
# image 1/1 /content/license_plate.jpg: 384x640 2 License-Plates, 8.6ms
# Speed: 2.5ms preprocess, 8.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# <PIL.Image.Image image mode=RGB size=639x360>

# %%
model.predict("/content/licence_video.mp4",save=True)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/635) /content/licence_video.mp4: 384x640 1 License-Plate, 6.2ms
# video 1/1 (frame 2/635) /content/licence_video.mp4: 384x640 (no detections), 6.1ms
# video 1/1 (frame 3/635) /content/licence_video.mp4: 384x640 (no detections), 6.1ms
# video 1/1 (frame 4/635) /content/licence_video.mp4: 384x640 1 License-Plate, 9.8ms
# video 1/1 (frame 5/635) /content/licence_video.mp4: 384x640 1 License-Plate, 6.0ms
# ...
